# %% [markdown]
# # Imports

# %%
import pandas as pd

# %% [markdown]
# # df

# %%
df = pd.read_csv('cinecomedies_scraper/cinecomedies_scraper/cinecomedies_box_office.csv')

# %%
df
# Out:
#                                               Titre  Entrées  Semaines
# 0              qu’est-ce qu’on a fait au bon dieu ?  1680249         1
# 1                                       babysitting   543729         1
# 2                                    need for speed   255242         1
# 3     the amazing spider-man : le destin d’un héros  1249001         1
# 4                                          barbecue   647797         1
# ...                                             ...      ...       ...
# 1332                       insidious : the red door   306107         1
# 1333           astérix & obélix : mission cléôpâtre   183334         1
# 1334                                        yo mama    78717         1
# 1335   mission impossible – dead reckoning partie 1   930141         1
# 1336                              les algues vertes   125566         1
#
# [1337 rows x 3 columns]

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1337 entries, 0 to 1336
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Titre     1195 non-null   object
#  1   Entrées   1337 non-null   int64
#  2   Semaines  1337 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 41.8+ KB

# %%
df['Titre'].value_counts()
# Out:
# joker                                   2
# qu’est-ce qu’on a fait au bon dieu ?    1
# en avant                                1
# nous les chiens                         1
# filles de joie                          1
#                                        ..
# sleepless                               1
# la tour sombre                          1
# annabelle 2 : la création du mal        1
# cars 3                                  1
# les algues vertes                       1
# Name: Titre, Length: 1194, dtype: int64

# %%
df['Titre'].isna().sum()
# Out:
# 142

# %%
df[df['Titre'].isna()]
# Out:
#      Titre  Entrées  Semaines
# 62     NaN   177913         1
# 65     NaN   147054         1
# 71     NaN   160365         1
# 73     NaN   128410         1
# 78     NaN   226546         1
# ...    ...      ...       ...
# 1196   NaN   147188         1
# 1200   NaN   119790         1
# 1258   NaN   101291         1
# 1319   NaN    95610         1
# 1329   NaN    91786         1
#
# [142 rows x 3 columns]

# %%
df = df[['Titre', 'Entrées']]

# %%
df = df.dropna()

# %%
df
# Out:
#                                               Titre  Entrées
# 0              qu’est-ce qu’on a fait au bon dieu ?  1680249
# 1                                       babysitting   543729
# 2                                    need for speed   255242
# 3     the amazing spider-man : le destin d’un héros  1249001
# 4                                          barbecue   647797
# ...                                             ...      ...
# 1332                       insidious : the red door   306107
# 1333           astérix & obélix : mission cléôpâtre   183334
# 1334                                        yo mama    78717
# 1335   mission impossible – dead reckoning partie 1   930141
# 1336                              les algues vertes   125566
#
# [1195 rows x 2 columns]

# %% [markdown]
# # df1

# %%
df1 = pd.read_csv('data/gold_senscritique.csv')

# %%
df1
# Out:
#                                         titre      sortie_france     entree  \
# 0                           en pleine tempête        9 août 2000  1403086.0
# 1                       escrocs mais pas trop    6 décembre 2000  1038868.0
# 2                      le prince du pacifique   20 décembre 2000  1028773.0
# 3                                billy elliot   20 décembre 2000  2514645.0
# 4             hollow man - l'homme sans ombre  20 septembre 2000  1512638.0
# ...                                       ...                ...        ...
# 3981                                   nevada       19 juin 2019   174181.0
# 3982  black snake, la légende du serpent noir    20 février 2019   174422.0
# 3983                                  perdrix       14 août 2019   143672.0
# 3984        la vérité si je mens ! les débuts    16 octobre 2019   193815.0
# 3985                         j’veux du soleil       3 avril 2019   185795.0
#
# ...

# %%
nouveau_nom_des_colonnes = {
    'titre': 'Titre',
    'entree': 'Entrée_totales',
    'annee': 'Année'
}

# Utiliser la méthode "rename" pour renommer les colonnes
df1.rename(columns=nouveau_nom_des_colonnes, inplace=True)

# %%
df1
# Out:
#                                         Titre      sortie_france  \
# 0                           en pleine tempête        9 août 2000
# 1                       escrocs mais pas trop    6 décembre 2000
# 2                      le prince du pacifique   20 décembre 2000
# 3                                billy elliot   20 décembre 2000
# 4             hollow man - l'homme sans ombre  20 septembre 2000
# ...                                       ...                ...
# 3981                                   nevada       19 juin 2019
# 3982  black snake, la légende du serpent noir    20 février 2019
# 3983                                  perdrix       14 août 2019
# 3984        la vérité si je mens ! les débuts    16 octobre 2019
# 3985                         j’veux du soleil       3 avril 2019
#
#       Entrée_totales  1er_semaine_estimation              acteur_1  \
# 0          1403086.0                  547204        George Clooney
# ...

# %%
df1[df1['Titre']== 'babysitting']
# Out:
#            Titre  sortie_france  Entrée_totales  1er_semaine_estimation  \
# 788  babysitting  16 avril 2014       2358733.0                  919906
#
#              acteur_1     acteur_2          acteur_3  duree      realisateur  \
# 788  Philippe Lacheau  Alice David  Vincent Desagnat   85.0  Nicolas Benamou
#
#      genre_1  genre_2  genre_3  note_film  franchise_1 franchise_2    pays  \
# 788  Comédie  Comédie  Comédie        5.6  Babysitting         NaN  France
#
#      Année
# 788   2014

# %%
df[df['Titre']== 'babysitting']
# Out:
#          Titre  Entrées
# 1  babysitting   543729

# %%
df["Titre"] = df["Titre"].str.replace("avatar : la voie de l’eau", "avatar - la voie de l'eau")

# %% [markdown]
# # df2

# %%
df2= pd.merge(df, df1, on='Titre', how='inner')

# %%
df2
# Out:
#                                          Titre  Entrées  sortie_france  \
# 0                                  babysitting   543729  16 avril 2014
# 1                                     barbecue   647797  30 avril 2014
# 2                                pas son genre   124082  30 avril 2014
# 3                                     godzilla   720996    14 mai 2014
# 4                              grace de monaco   152404    14 mai 2014
# ..                                         ...      ...            ...
# 723                                  the flash   388700   14 juin 2023
# 724                                élémentaire   426818   21 juin 2023
# 725                              asteroid city   117498   21 juin 2023
# 726  indiana jones et le cadran de la destinée  1089875   28 juin 2023
# 727         les vengeances de maître poutifard   180735   28 juin 2023
#
#      Entrée_totales  1er_semaine_estimation              acteur_1  \
# ...

# %%
# Sélectionner les lignes contenant l'un des mots spécifiés dans la colonne "Titre"
selected_rows = df1[df1["Titre"].str.contains(r"les 4 fantastiques|coco|robin des bois|la belle et la bête|avatar")]

# Afficher les lignes sélectionnées
print(selected_rows)
# Out:
#                                          Titre     sortie_france  \
# 222                         les 4 fantastiques   20 juillet 2005
# 302   les 4 fantastiques et le surfer d'argent       8 août 2007
# 373                          coco avant chanel     22 avril 2009
# 404                                     avatar  16 décembre 2009
# 407                                       coco      18 mars 2009
# 474                      robin des bois - 2010       12 mai 2010
# 688                 la belle et la bête - 2014   12 février 2014
# 754                  les 4 fantastiques reboot       5 août 2015
# 763     robin des bois : la véritable histoire     15 avril 2015
# 957                 la belle et la bête - 2017      22 mars 2017
# 977                                coco disney  29 novembre 2017
# 1104                     robin des bois - 2018  28 novembre 2018
# 1797                 avatar - la voie de l'eau  14 décembre 2022
# ...

# %% [markdown]
# # Estimation du pourcentage des entrées dans le 1ère semaine

# %%
df2['Pourcentage_semaine_totales'] = (df2['Entrées']*100)/ df2['Entrée_totales']

# %%
df2
# Out:
#                                          Titre  Entrées  sortie_france  \
# 0                                  babysitting   543729  16 avril 2014
# 1                                     barbecue   647797  30 avril 2014
# 2                                pas son genre   124082  30 avril 2014
# 3                                     godzilla   720996    14 mai 2014
# 4                              grace de monaco   152404    14 mai 2014
# ..                                         ...      ...            ...
# 723                                  the flash   388700   14 juin 2023
# 724                                élémentaire   426818   21 juin 2023
# 725                              asteroid city   117498   21 juin 2023
# 726  indiana jones et le cadran de la destinée  1089875   28 juin 2023
# 727         les vengeances de maître poutifard   180735   28 juin 2023
#
#      Entrée_totales  1er_semaine_estimation              acteur_1  \
# ...

# %%
df[df['Titre'] == "avatar - la voie de l'eau"]
# Out:
#                           Titre  Entrées
# 1243  avatar - la voie de l'eau  2739848

# %%
df2[df2['Année'] != 2023]['Pourcentage_semaine_totales'].mean()
# Out:
# 39.99054411857803

# %%
df2[df2['Pourcentage_semaine_totales'] >= 60.000000]
# Out:
#                                    Titre  Entrées      sortie_france  \
# 29                            the search    53211   26 novembre 2014
# 80                   arrête ton cinéma !    83248    13 janvier 2016
# 81                            et ta sœur    81813    13 janvier 2016
# 83                             le convoi    96050    20 janvier 2016
# 86                        encore heureux   224459    27 janvier 2016
# 100                        la dream team   137639       23 mars 2016
# 156                                 iris   102231   16 novembre 2016
# 159                           oppression    56727   30 novembre 2016
# 165                          mes trésors    99200     4 janvier 2017
# 177                      a cure for life   152375    15 février 2017
# 182                          john wick 2   201953    22 février 2017
# 247                             geostorm   235162    1 novembre 2017
# 250                     tout nous sépare   101574    8 novembre 2017
# ...

# %% [markdown]
# # df3

# %%
df3 = df1.merge(df2[["Titre", "Entrées"]], on="Titre", how="left")

# %%
df3
# Out:
#                                         Titre      sortie_france  \
# 0                           en pleine tempête        9 août 2000
# 1                       escrocs mais pas trop    6 décembre 2000
# 2                      le prince du pacifique   20 décembre 2000
# 3                                billy elliot   20 décembre 2000
# 4             hollow man - l'homme sans ombre  20 septembre 2000
# ...                                       ...                ...
# 3996                                   nevada       19 juin 2019
# 3997  black snake, la légende du serpent noir    20 février 2019
# 3998                                  perdrix       14 août 2019
# 3999        la vérité si je mens ! les débuts    16 octobre 2019
# 4000                         j’veux du soleil       3 avril 2019
#
#       Entrée_totales  1er_semaine_estimation              acteur_1  \
# 0          1403086.0                  547204        George Clooney
# ...

# %%
df3['Entrées_1ere_semaine'] = df3['Entrées'].fillna(df1['1er_semaine_estimation'])

# %%
df3
# Out:
#                                         Titre      sortie_france  \
# 0                           en pleine tempête        9 août 2000
# 1                       escrocs mais pas trop    6 décembre 2000
# 2                      le prince du pacifique   20 décembre 2000
# 3                                billy elliot   20 décembre 2000
# 4             hollow man - l'homme sans ombre  20 septembre 2000
# ...                                       ...                ...
# 3996                                   nevada       19 juin 2019
# 3997  black snake, la légende du serpent noir    20 février 2019
# 3998                                  perdrix       14 août 2019
# 3999        la vérité si je mens ! les débuts    16 octobre 2019
# 4000                         j’veux du soleil       3 avril 2019
#
#       Entrée_totales  1er_semaine_estimation              acteur_1  \
# 0          1403086.0                  547204        George Clooney
# ...

# %%
df3.drop(columns=["1er_semaine_estimation", "Entrées"], inplace=True)

# %%
df3
# Out:
#                                         Titre      sortie_france  \
# 0                           en pleine tempête        9 août 2000
# 1                       escrocs mais pas trop    6 décembre 2000
# 2                      le prince du pacifique   20 décembre 2000
# 3                                billy elliot   20 décembre 2000
# 4             hollow man - l'homme sans ombre  20 septembre 2000
# ...                                       ...                ...
# 3996                                   nevada       19 juin 2019
# 3997  black snake, la légende du serpent noir    20 février 2019
# 3998                                  perdrix       14 août 2019
# 3999        la vérité si je mens ! les débuts    16 octobre 2019
# 4000                         j’veux du soleil       3 avril 2019
#
#       Entrée_totales              acteur_1             acteur_2  \
# 0          1403086.0        George Clooney        Mark Wahlberg
# ...

# %%
df3['Entrées_1ere_semaine'].isna().sum()
# Out:
# 13

# %%
df3 = df3.dropna(subset=['Entrées_1ere_semaine'])

# %%
df3
# Out:
#                                   Titre      sortie_france  Entrée_totales  \
# 0                     en pleine tempête        9 août 2000       1403086.0
# 1                 escrocs mais pas trop    6 décembre 2000       1038868.0
# 2                le prince du pacifique   20 décembre 2000       1028773.0
# 3                          billy elliot   20 décembre 2000       2514645.0
# 4       hollow man - l'homme sans ombre  20 septembre 2000       1512638.0
# ...                                 ...                ...             ...
# 3983                mais vous êtes fous      24 avril 2019        101540.0
# 3984  vous êtes jeunes, vous êtes beaux     2 octobre 2019          4986.0
# 3985                 salauds de pauvres                NaN            50.0
# 3998                            perdrix       14 août 2019        143672.0
# 3999  la vérité si je mens ! les débuts    16 octobre 2019        193815.0
#
# ...

# %% [markdown]
# # Création d'un fichier csv

# %%
df3.to_csv('data/gold.data.csv', index=False)
