# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df =pd.read_csv("allocine_sortie.csv") 
df_max =pd.read_csv("allocine_2.csv")

# %%
df_max.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110550 entries, 0 to 110549
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   titre             110549 non-null  object
#  1   acteur_1          83218 non-null   object
#  2   acteur_2          79992 non-null   object
#  3   acteur_3          76757 non-null   object
#  4   réalisateur       97261 non-null   object
#  5   distributeur      28467 non-null   object
#  6   note_presse       63960 non-null   object
#  7   duree             78469 non-null   float64
#  8   genre             53373 non-null   object
#  9   pays              88091 non-null   object
#  10  type              110549 non-null  object
#  11  nominations       110550 non-null  int64
#  12  prix              110550 non-null  int64
#  13  annee_production  99993 non-null   float64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 11.8+ MB

# %%
df
# Out:
#                               titre              acteur_1  \
# 0                   Le Manoir hanté        Rosario Dawson
# 1                   Un hiver en été       Benjamin Biolay
# 2                          Sabotage          Ariela Barer
# 3                    Sur la branche        Daphne Patakia
# 4                           La Main          Sophie Wilde
# 5                      Les Déguns 2           Karim Jebli
# 6        Les Damnés ne pleurent pas          Aïcha Tebbae
# 7                           Juniors       Vanessa Paradis
# 8   Rocky Aur Rani Kii Prem Kahaani         Ranveer Singh
# 9                   Portier de nuit          Dirk Bogarde
# 10          LGM : Let’s get Married         Harish Kalyan
# 11              Rendez-vous à Tokyo       Sosuke Ikematsu
# 12                          Nazarín       Francisco Rabal
# 13   La Vache qui chantait le futur         Léonor Varela
# 14              The First Slam Dunk        Shugo Nakamura
# ...

# %%
print(df.columns)
# Out:
# Index(['titre', 'acteur_1', 'acteur_2', 'acteur_3', 'réalisateur',
#        'distributeur', 'note_presse', 'note_spectateur', 'duree', 'genre',
#        'pays', 'type', 'budget', 'nominations', 'prix', 'description', 'date',
#        'annee_production'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   titre             22 non-null     object
#  1   acteur_1          21 non-null     object
#  2   acteur_2          21 non-null     object
#  3   acteur_3          21 non-null     object
#  4   réalisateur       22 non-null     object
#  5   distributeur      22 non-null     object
#  6   note_presse       20 non-null     object
#  7   note_spectateur   15 non-null     object
#  8   duree             22 non-null     int64
#  9   genre             22 non-null     object
#  10  pays              22 non-null     object
#  11  type              22 non-null     object
#  12  budget            3 non-null      float64
#  13  nominations       22 non-null     int64
#  14  prix              22 non-null     int64
#  15  description       22 non-null     object
# ...
