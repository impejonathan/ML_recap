# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# import folium   
# from branca.element import Figure    
import plotly.express as px
# import nbformat
pd.set_option('display.max_columns', None)

df = pd.read_csv("data/allocine_bronze.csv")

# %%
# # Supposons que votre DataFrame s'appelle df
# df = df.rename(columns={'réalisateur ': 'réalisateur', 'distributeur ': 'distributeur'})

# %%
df.columns
# Out:
# Index(['titre', 'acteur_1', 'acteur_2', 'acteur_3', 'réalisateur',
#        'distributeur', 'note_presse', 'duree', 'genre', 'pays', 'type',
#        'nominations', 'prix', 'annee_production', 'Semaine',
#        'Entrées_1ère_semaine'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8637 entries, 0 to 8636
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   titre                 8637 non-null   object
#  1   acteur_1              8434 non-null   object
#  2   acteur_2              8434 non-null   object
#  3   acteur_3              8434 non-null   object
#  4   réalisateur           8629 non-null   object
#  5   distributeur          8398 non-null   object
#  6   note_presse           8637 non-null   float64
#  7   duree                 8637 non-null   int64
#  8   genre                 8473 non-null   object
#  9   pays                  8623 non-null   object
#  10  type                  8637 non-null   object
#  11  nominations           8637 non-null   int64
#  12  prix                  8637 non-null   int64
#  13  annee_production      8637 non-null   int64
#  14  Semaine               8637 non-null   object
# ...

# %% [markdown]
# <font color='red'><h2>Répartition des films par bloc d'année de 10 </h2></font>

# %%
# Création d'un masque pour les blocs de 10 ans
annee_bloc = (df['annee_production'] // 5) * 5

# Affichage des données par blocs de 10 ans en utilisant le masque
sns.countplot(y=annee_bloc, data=df)
plt.ylabel("Année")
plt.xlabel("Nombre de films")
plt.title("Répartition des films par blocs de 10 ans")
plt.show()

# %% [markdown]
#   <font color='red'><h2> Nuage de mots pour genre_1  moyen </h2></font>

# %%
! pip install wordcloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Créer une série avec les genres de films et leur nombre de films
data = df['genre'].value_counts()

# Créer le nuage de mots avec WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white')
wordcloud.generate_from_frequencies(data)

# Afficher le nuage de mots
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Nuage de mots montrant les genres de films les plus populaires en fonction du nombre de films dans chaque genre")
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Créer une série avec les genres de films et leur nombre d'entrées lors de leur première semaine
data = df.groupby('genre')['Entrées_1ère_semaine'].sum()

# Créer le nuage de mots avec WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white')
wordcloud.generate_from_frequencies(data)

# Afficher le nuage de mots
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Nuage de mots montrant les genres de films les plus populaires en fonction de leur nombre d'entrées lors de leur première semaine")
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Créer une série avec les genres de films et leur nombre de films
data = df['pays'].value_counts()

# Créer le nuage de mots avec WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white')
wordcloud.generate_from_frequencies(data)

# Afficher le nuage de mots
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Nuage de mots montrant les genres de films les plus populaires en fonction du nombre de films dans chaque genre")
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Créer une série avec les genres de films et leur nombre d'entrées lors de leur première semaine
data = df.groupby('pays')['Entrées_1ère_semaine'].sum()

# Créer le nuage de mots avec WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white')
wordcloud.generate_from_frequencies(data)

# Afficher le nuage de mots
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Nuage de mots montrant les genres de films les plus populaires en fonction de leur nombre d'entrées lors de leur première semaine")
plt.show()

# %%
# Supposons que votre DataFrame s'appelle df_box_office et qu'il contient les colonnes "titre", "entree" et "annee"
top_13 = df.sort_values(by="Entrées_1ère_semaine", ascending=False).head(13)

plt.figure(figsize=(10, 6))
sns.barplot(y="titre", x="Entrées_1ère_semaine", data=top_13)
plt.ylabel("Titre")
plt.xlabel("Nombre d'entrées")
plt.title("Les 13 films les plus vus")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8637 entries, 0 to 8636
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   titre                 8637 non-null   object
#  1   acteur_1              8434 non-null   object
#  2   acteur_2              8434 non-null   object
#  3   acteur_3              8434 non-null   object
#  4   réalisateur           8629 non-null   object
#  5   distributeur          8398 non-null   object
#  6   note_presse           8637 non-null   float64
#  7   duree                 8637 non-null   int64
#  8   genre                 8473 non-null   object
#  9   pays                  8623 non-null   object
#  10  type                  8637 non-null   object
#  11  nominations           8637 non-null   int64
#  12  prix                  8637 non-null   int64
#  13  annee_production      8637 non-null   int64
#  14  Semaine               8637 non-null   object
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Supposons que votre DataFrame s'appelle df
top_20 = df.sort_values(by='Entrées_1ère_semaine', ascending=False).head(20)

plt.figure(figsize=(12,6))
sns.barplot(data=top_20, x='Entrées_1ère_semaine', y='titre', hue='pays')
plt.legend(title='Pays', bbox_to_anchor=(1.05, 1), loc=2)
plt.title('Top 20 des films les plus vus par pays')
plt.xlabel('Entrées 1ère semaine')
plt.ylabel('Titre du film')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Groupby sur "franchise_1"
df_grouped = df.groupby('distributeur').sum().reset_index()

# Trier les données par "entree" en ordre décroissant et sélectionner les 10 premières lignes
df_top10 = df_grouped.sort_values('Entrées_1ère_semaine', ascending=False).head(13)

# Création du graphique
sns.barplot(data=df_top10, x='Entrées_1ère_semaine', y='distributeur')
plt.title('Top 10 des franchises par entrées')
plt.show()
# Out:
# C:\Users\impej\AppData\Local\Temp\ipykernel_21160\3085439736.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_grouped = df.groupby('distributeur').sum().reset_index()

# %%
print(df.columns)
# Out:
# Index(['titre', 'acteur_1', 'acteur_2', 'acteur_3', 'réalisateur',
#        'distributeur', 'note_presse', 'duree', 'genre', 'pays', 'type',
#        'nominations', 'prix', 'annee_production', 'Semaine',
#        'Entrées_1ère_semaine'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# Groupby sur "pays"
df_grouped = df.groupby('pays').sum().reset_index()

# Calcul du total des entrées
total_entree = df_grouped['Entrées_1ère_semaine'].sum()

# Filtrage des données pour ne garder que les films ayant plus de 2% des entrées totales
df_filtered = df_grouped[df_grouped['Entrées_1ère_semaine'] > total_entree * 0.02]

# Création du graphique
plt.pie(df_filtered['Entrées_1ère_semaine'], labels=df_filtered['pays'], autopct='%1.1f%%')
plt.title('Entrées par pays (films ayant plus de 2% des entrées totales)')
plt.show()
# Out:
# C:\Users\impej\AppData\Local\Temp\ipykernel_21160\4080591264.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_grouped = df.groupby('pays').sum().reset_index()

# %%
import matplotlib.pyplot as plt

# Groupby sur "pays"
df_grouped = df.groupby('pays').count().reset_index()

# Calcul du total des titres
total_titres = df_grouped['titre'].sum()

# Filtrage des données pour ne garder que les films ayant plus de 2% des titres totaux
df_filtered = df_grouped[df_grouped['titre'] > total_titres * 0.02]

# Création du graphique
plt.pie(df_filtered['titre'], labels=df_filtered['pays'], autopct='%1.1f%%')
plt.title('Titres par pays (films ayant plus de 2% des titres totaux)')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt

# Sélectionner les colonnes numériques de df
df_numeric = df.select_dtypes(include='number')

# Créer une copie de df pour éviter de modifier le DataFrame original
df_copy = df.copy()

# Encoder les variables catégorielles avec LabelEncoder
le = LabelEncoder()
categorical_columns = ['titre', 'acteur_1', 'acteur_2', 'acteur_3', 'réalisateur', 'distributeur', 'genre', 'pays', 'type', 'Semaine']
for col in categorical_columns:
    df_copy[col] = le.fit_transform(df_copy[col].astype(str))

# Sélectionner les colonnes encodées de df_copy
df_encoded = df_copy[categorical_columns]

# Concaténer les colonnes numériques et les colonnes encodées
df_concat = pd.concat([df_numeric, df_encoded], axis=1)

# Créer la matrice de corrélation pour les colonnes numériques et encodées de df_concat
corr_matrix = df_concat.corr()

# Sélectionner uniquement la colonne cible 'Entrées_1ère_semaine'
corr_target = corr_matrix[['Entrées_1ère_semaine']]

# Trier les valeurs par ordre décroissant de corrélation avec la colonne cible
corr_target = corr_target.sort_values(by='Entrées_1ère_semaine', ascending=False)

# Créer la heatmap avec Seaborn
fig, ax = plt.subplots(figsize=(5, 12))
sns.heatmap(corr_target, cmap='coolwarm', annot=True, ax=ax)
plt.title("Heatmap montrant la corrélation entre les différentes colonnes de df et la colonne cible 'Entrées_1ère_semaine'")
plt.show()
